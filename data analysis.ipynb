# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
fast_food_data = pd.read_csv ('FastFoodRestaurants.csv')
fast_food_data
# Out:
#                     address                    city country  \
# 0               324 Main St                 Massena      US
# 1           530 Clinton Ave  Washington Court House      US
# 2      408 Market Square Dr               Maysville      US
# 3     6098 State Highway 37                 Massena      US
# 4           139 Columbus Rd                  Athens      US
# ...                     ...                     ...     ...
# 9995  3013 Peach Orchard Rd                 Augusta      US
# 9996      678 Northwest Hwy                    Cary      US
# 9997           1708 Main St                Longmont      US
# 9998      67740 Highway 111          Cathedral City      US
# 9999    5701 E La Palma Ave                 Anaheim      US
#
#                                                    keys   latitude  \
# 0                   us/ny/massena/324mainst/-1161002137  44.921300
# 1     us/oh/washingtoncourthouse/530clintonave/-7914...  39.532550
# ...

# %%
data_set = fast_food_data[["address", "city","country","latitude","longitude","name","postalCode","province"]]
data_set
# Out:
#                     address                    city country   latitude  \
# 0               324 Main St                 Massena      US  44.921300
# 1           530 Clinton Ave  Washington Court House      US  39.532550
# 2      408 Market Square Dr               Maysville      US  38.627360
# 3     6098 State Highway 37                 Massena      US  44.950080
# 4           139 Columbus Rd                  Athens      US  39.351550
# ...                     ...                     ...     ...        ...
# 9995  3013 Peach Orchard Rd                 Augusta      US  33.415257
# 9996      678 Northwest Hwy                    Cary      US  42.217300
# 9997           1708 Main St                Longmont      US  40.189190
# 9998      67740 Highway 111          Cathedral City      US  33.788640
# 9999    5701 E La Palma Ave                 Anaheim      US  33.860074
#
#        longitude                         name postalCode province
# ...

# %%
data_set["name"].value_counts()
# Out:
# name
# McDonald's                      1886
# Burger King                     1154
# Taco Bell                        873
# Wendy's                          731
# Arby's                           518
#                                 ...
# Charcoal Delights                  1
# Jim's Coney Island                 1
# The Great Steak & Potato Co.       1
# Hot Dog Heaven                     1
# Lee's Oriental Martial Arts        1
# Name: count, Length: 548, dtype: int64

# %%
# check about datatypes and nulls
data_set.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   address     10000 non-null  object
#  1   city        10000 non-null  object
#  2   country     10000 non-null  object
#  3   latitude    10000 non-null  float64
#  4   longitude   10000 non-null  float64
#  5   name        10000 non-null  object
#  6   postalCode  10000 non-null  object
#  7   province    10000 non-null  object
# dtypes: float64(2), object(6)
# memory usage: 625.1+ KB

# %%
#display of the density of fast food restaurant in all the  provinces across the US

plt.figure(figsize=(20, 5))
sns.histplot(data_set['province'], kde=True, bins=15)
# Out:
# <Axes: xlabel='province', ylabel='Count'>

# %%
# # top 10 province with fast food restaurants provinces
df = data_set["province"].value_counts()[:10]
df
# Out:
# province
# CA    676
# TX    634
# OH    543
# FL    471
# IN    379
# IL    363
# NC    358
# GA    347
# MO    334
# KY    332
# Name: count, dtype: int64

# %%
plt.figure(figsize=(20, 5))
df.plot(kind='bar', color='purple')
plt.title('Number of fast-food restaurant per Province', fontsize=14)
plt.xlabel('Province')
plt.ylabel('Frequency')
plt.show()

# %%
df = data_set.groupby(["name", "postalCode"]).size().nlargest()
df
# Out:
# name         postalCode
# McDonald's   23185         5
#              4401          4
# Taco Bell    41042         4
# Arby's       45069         3
#              57701         3
# Burger King  33311         3
#              44035         3
#              63376         3
#              98032         3
# Hardee's     57701         3
# dtype: int64

# %%
#top 10 zip code with detailed restaurants occupation

df= df.unstack()
top_postal_codes = df.sum(axis=0).nlargest(10).index
top_counts = df[top_postal_codes]
top_counts.plot(kind='bar', figsize=(10, 6))
plt.xlabel('fastfood restaurants')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
df
# Out:
# postalCode   23185  4401  41042  45069  57701  33311  44035  63376  98032
# name
# McDonald's     5.0   4.0    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# Taco Bell      NaN   NaN    4.0    NaN    NaN    NaN    NaN    NaN    NaN
# Arby's         NaN   NaN    NaN    3.0    3.0    NaN    NaN    NaN    NaN
# Burger King    NaN   NaN    NaN    NaN    NaN    3.0    3.0    3.0    3.0
# Hardee's       NaN   NaN    NaN    NaN    3.0    NaN    NaN    NaN    NaN
